# %%
## Works! Returns string of Spider Man's aliases and list of his enemies
## http://comicvine.gamespot.com/api/character/4005-1443/?api_key=aff8790cd32512f45b429bb78cc21a7a87cf4d48&field_list=aliases,character_enemies

# %%
villains = {"Vulture", "Doctor Octopus", "Chameleon", "Tinkerer", "Sandman", "Lizard", "Electro", "Mysterio", "Green Goblin", "Kraven the Hunter", "Scorpion", "Rhino", "Shocker", "Kingpin", "Morbius", "Jackal", "Hobgoblin", "Carnage", "Man-Wolf"}

for v in villains:
    print(v)

# %%
import urllib2
import json



req = urllib2.Request('http://comicvine.gamespot.com/api/search/?format=json&api_key=aff8790cd32512f45b429bb78cc21a7a87cf4d48&query=spider+man&resource_type=character/')

req.add_header('User-agent', 'Mozilla 5.10')

res = urllib2.urlopen(req)

data = json.load(res)

print(data)
# Out:
# {u'number_of_page_results': 98, u'status_code': 1, u'error': u'OK', u'results': [{u'origin': {u'api_detail_url': u'http://comicvine.gamespot.com/api/origin/4030-1/', u'id': 1, u'name': u'Mutant'}, u'publisher': {u'api_detail_url': u'http://comicvine.gamespot.com/api/publisher/4010-31/', u'id': 31, u'name': u'Marvel'}, u'date_last_updated': u'2013-09-17 05:29:16', u'description': u'<h2>Creation</h2><p>Spiders Man was created by <a href="/alex-ross/4040-10945/" data-ref-id="4040-10945">Alex Ross</a>, <a href="/jim-krueger/4040-41498/" data-ref-id="4040-41498">Jim Krueger</a> and <a href="//www.comicvine.com/john-paul-leon/4040-19216/" data-ref-id="4040-19216">John Paul Leon</a> and first appeared in <a href="/earth-x/4050-6354/" data-ref-id="4050-6354"><em>Earth X</em></a> #4.</p><h2>Powers and Abilities</h2><p>Spiders Man has the ability to weave psychic webs that induces illusions in people.</p>', u'deck': u'Spiders Man is a reptilian-esque illusion caster and a former follower of The Skull and member of the Universal Church of Immortus.', u'gender': 1, u'image': {u'icon_url': u'http://comicvine.gamespot.com/api/image/square_avatar/671040-spiders_man.jpg', u'medium_url': u'http://comicvine.gamespot.com/api/image/scale_medium/671040-spiders_man.jpg', u'tiny_url': u'http://comicvine.gamespot.com/api/image/square_mini/671040-spiders_man.jpg', u'small_url': u'http://comicvine.gamespot.com/api/image/scale_small/671040-spiders_man.jpg', u'thumb_url': u'http://comicvine.gamespot.com/api/image/scale_avatar/671040-spiders_man.jpg', u'screen_url': u'http://comicvine.gamespot.com/api/image/screen_medium/671040-spiders_man.jpg', u'super_url': u'http://comicvine.gamespot.com/api/image/scale_large/671040-spiders_man.jpg'}, u'site_detail_url': u'http://comicvine.gamespot.com/spiders-man/4005-46814/', u'first_appeared_in_issue': {u'api_detail_url': u'http://comicvine.gamespot.com/api/first_appeared_in_issue/4000-249043/', u'issue_number': u'1', u'id': 249043, u'name': u'Earth X Sketchbook'}, u'name': u'Spiders Man', u'api_detail_url': u'http://comicvine.gamespot.com/api/character/4005-46814/', u'count_of_issue_appearances': 24, u'birth': None, u'date_added': u'2008-06-06 11:27:27', u'real_name': None, u'id': 46814, u'resource_type': u'character', u'aliases': u"Spider's Man"}, {u'origin': {u'api_detail_url': u'http://comicvine.gamespot.com/api/origin/4030-6/', u'id': 6, u'name': u'Radiation'}, u'publisher': {u'api_detail_url': u'http://comicvine.gamespot.com/api/publisher/4010-31/', u'id': 31, u'name': u'Marvel'}, u'date_last_updated': u'2016-08-10 11:43:49', u'description': u'<h2>Current Events</h2><p>The <a href="/spider-verse/4045-58072/" data-ref-id="4045-58072">Spider-Verse</a> event is over and Spider-Man returns home to move on with his life. Initially, Peter wanted to construct a special prison to rehabilitate superhuman criminals, but such plans are interrupted when corporate criminal <a href="/ghost/4005-17638/" data-ref-id="4005-17638">Ghost</a> attacks <a href="/parker-industries/4020-59287/" data-ref-id="4020-59287">Parker Industries</a>. Spider-Man defeats the Ghost but Parker Industries burns to the ground.</p><h2>Origin</h2><figure data-size="small" data-align="right" data-ref-id="1300-127622" data-img-src="http://static.comicvine.com/uploads/original/0/3848/127622-130694-spider-man.jpg" data-ratio="0.73513513513514" data-width="185" data-embed-type="image" style="width: 185px"><a class="fluid-height" style="padding-bottom:73.5%" href="http://static.comicvine.com/uploads/original/0/3848/127622-130694-spider-man.jpg" data-ref-id="1300-127622"><img alt="Birth of Spider-Man" src="http://static3.comicvine.com/uploads/original/0/3848/127622-130694-spider-man.jpg" srcset="http://static3.comicvine.com/uploads/original/0/3848/127622-130694-spider-man.jpg 185w" sizes="(max-width: 185px) 100vw, 185px" data-width="185"></a><figcaption>Birth of Spider-Man</figcaption></figure><p>Peter Benjamin Parker was born to C.I.A. agents <a href="../. ...
